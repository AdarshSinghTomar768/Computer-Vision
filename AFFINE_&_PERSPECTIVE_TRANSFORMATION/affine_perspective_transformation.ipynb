# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # PERSPECTIVE TRANSFORMATION

# %%
image = cv2.imread("bgr_image.png")

# %%
plt.imshow(image)

# %%
rgb_image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
rows, cols, _ = rgb_image.shape

input_points = np.float32([[50,50],[cols-50,50],[50,rows-50],[cols-50,rows-50]])

output_points = np.float32([[10,100],[cols-100,50],[100,rows-10],[cols-50,rows-100]])

M = cv2.getPerspectiveTransform(input_points,output_points)
print(M)
# Out:
# [[ 1.31414129e+00  4.09752040e-01 -7.50412920e+01]
#  [-2.42375605e-01  1.40246651e+00  5.35291978e+01]
#  [ 1.48963240e-03  8.17116197e-04  1.00000000e+00]]

# %%
perspective_image = cv2.warpPerspective(rgb_image,M,(cols,rows))

plt.Figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(rgb_image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(perspective_image)
plt.title("Perspective Transformed Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(275.5), np.float64(405.5), np.float64(-0.5))

# %% [markdown]
# # AFFINE TRANSFORMATION

# %%
input_points = np.float32([[50,50],[200,50],[50,200]])

output_points = np.float32([[10,100],[200,50],[100,250]])

M = cv2.getAffineTransform(input_points,output_points)

affine_image = cv2.warpAffine(rgb_image,M,(cols,rows))


plt.Figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(rgb_image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(affine_image)
plt.title("Affine Transformation Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(275.5), np.float64(405.5), np.float64(-0.5))

# %% [markdown]
# # ROTATION

# %%
angle = 90
center = (cols // 2, rows // 2)
scale = 1.0

M = cv2.getRotationMatrix2D(center,angle,scale)

rotated_image = cv2.warpAffine(rgb_image,M,(rows,cols))

plt.Figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(rgb_image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(rotated_image)
plt.title("Affine Rotated Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(405.5), np.float64(275.5), np.float64(-0.5))

# %% [markdown]
# # SHEARING

# %%
# angle = 90
# center = (cols // 2, rows // 2)
# scale = 1.0
shear_x ,shear_y = 0.5,0

M = np.float32([[1,shear_x,0],[shear_y,1,0]])

sheared_image = cv2.warpAffine(rgb_image,M,(cols + int(shear_x * rows),rows))

plt.Figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(rgb_image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(sheared_image)
plt.title("Affine Sheared Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(478.5), np.float64(405.5), np.float64(-0.5))

# %% [markdown]
# # TRANSLATION

# %%
# angle = 90
# center = (cols // 2, rows // 2)
# scale = 1.0
Tx ,Ty = 50, 35

M = np.float32([[1,0,Tx],[0,1,Ty]])

translated_image = cv2.warpAffine(rgb_image,M,(cols,rows))

plt.Figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(rgb_image)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(translated_image)
plt.title("Affine Translated Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(275.5), np.float64(405.5), np.float64(-0.5))
